# %% [markdown]
# # 🎤 Faster-Whisper STT Server (Transcription + Translation)
# ## AI Voice Assistant — Remote Speech-to-Text & English Translation API
#
# This notebook:
# 1. Installs Faster-Whisper + Flask + pyngrok
# 2. Loads `deepdml/faster-whisper-large-v3-turbo-ct2` (Primary STT)
# 3. Loads `Systran/faster-whisper-large-v3` (Speech-to-English Translation)
# 4. Exposes a `POST /transcribe` endpoint returning both `text` (original transcript) and `translated_text` (English translation)
#
# ### Execution Order
# 1. **Runtime → Change runtime type → T4 GPU** (or A100 if available)
# 2. Run **Cell 1** (install packages)
# 3. Run **Cell 2** (paste your ngrok auth token)
# 4. Run **Cell 3** (load primary STT model)
# 5. Run **Cell 4** (load translation model)
# 6. Run **Cell 5** (start Flask API & ngrok tunnel — copy the `https://...ngrok-free.app` URL)
#
# ---
# > **Keep the notebook running.** If Colab disconnects, re-run Cells 2–5 and update your `.env`.

# %%
# -- Cell 1: Install dependencies ------------------------------------------
import subprocess, sys
subprocess.run(
    [sys.executable, '-m', 'pip', 'install', '-q',
     'faster-whisper', 'ctranslate2', 'flask', 'pyngrok'],
    check=True
)

# %%
# ── Cell 2: Configure ngrok auth token ────────────────────────────────
# Get a free token at: https://dashboard.ngrok.com/get-started/your-authtoken
from pyngrok import ngrok

NGROK_AUTH_TOKEN = "3GVVwR1jvZi289NAF5BsE6oquUg_4npcsz2Thw1UEu2WyTFGJ"  # <-- paste your ngrok auth token here

if not NGROK_AUTH_TOKEN:
    raise ValueError(
        "Please set your ngrok auth token in NGROK_AUTH_TOKEN above.\n"
        "Get it free at: https://dashboard.ngrok.com/get-started/your-authtoken"
    )

ngrok.set_auth_token(NGROK_AUTH_TOKEN)
print("ngrok auth token configured.")

# %%
# ── Cell 3: Load existing Faster-Whisper primary STT model ────────────
import os
import re
import time
import logging
from faster_whisper import WhisperModel

logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
logger = logging.getLogger(__name__)

# ── Primary STT Model configuration (UNTOUCHED) ────────────────────────
MODEL_ID     = "deepdml/faster-whisper-large-v3-turbo-ct2"
DEVICE       = "cuda"   # GPU — make sure Colab runtime is set to GPU
COMPUTE_TYPE = "float16"
BEAM_SIZE    = 5
VAD_FILTER   = True

# ── Load existing Faster-Whisper model once at startup ─────────────────
print(f"Loading Faster-Whisper model '{MODEL_ID}' on {DEVICE} …")
load_start = time.perf_counter()

model = WhisperModel(MODEL_ID, device=DEVICE, compute_type=COMPUTE_TYPE)

print(f"Model loaded in {time.perf_counter() - load_start:.1f}s")

# ── Text cleaning helper ───────────────────────────────────────────────
def _clean_text(text: str) -> str:
    text = re.sub(r"\s+", " ", text).strip()
    text = re.sub(r"\s+([.,!?;:])", r"\1", text)
    return text

# %%
# ── Cell 4: Load translation model + helper ───────────────────────────
TRANSLATION_MODEL_ID = "Systran/faster-whisper-large-v3"

print(f"Loading translation model '{TRANSLATION_MODEL_ID}' on {DEVICE} …")
translation_load_start = time.perf_counter()

translation_model = WhisperModel(
    TRANSLATION_MODEL_ID,
    device=DEVICE,
    compute_type=COMPUTE_TYPE,
)

print(f"Translation model loaded in {time.perf_counter() - translation_load_start:.1f}s")

def translate_audio_to_english(audio_path: str) -> str:
    """Perform a speech-to-English translation pass using the multilingual model."""
    translation_segments, translation_info = translation_model.transcribe(
        audio_path,
        language=None,
        task="translate",
        beam_size=BEAM_SIZE,
        vad_filter=VAD_FILTER,
    )
    translated_parts = [
        segment.text
        for segment in translation_segments
    ]
    translated_text = " ".join(translated_parts).strip()
    return _clean_text(translated_text)

# %%
# ── Cell 5: Start Flask + ngrok server ────────────────────────────────
import tempfile
import threading
from flask import Flask, request, jsonify
from pyngrok import ngrok

app = Flask(__name__)

@app.route("/health", methods=["GET"])
def health():
    """Simple health-check endpoint."""
    return jsonify({
        "status": "ok",
        "model": MODEL_ID,
        "translation_model": TRANSLATION_MODEL_ID,
        "device": DEVICE,
    })

@app.route("/transcribe", methods=["POST"])
def transcribe():
    """
    POST /transcribe
    ----------------
    multipart/form-data:
        audio  — audio file Faster-Whisper supports (wav, mp3, webm, ogg …)

    Response (JSON):
        {
            "text":                        str (original transcription),
            "translated_text":            str (English translation),
            "raw_text":                    str,
            "language":                    str,
            "language_probability":        float,
            "duration":                    float,
            "processing_time":             float,
            "translation_processing_time": float,
            "segments":                    list
        }
    """
    if "audio" not in request.files:
        return jsonify({"error": "No audio file provided. Use multipart/form-data with key 'audio'."}), 400

    audio_file = request.files["audio"]
    filename   = audio_file.filename or "audio"

    suffix = ".wav"
    if "." in filename:
        suffix = "." + filename.rsplit(".", 1)[1].lower()

    fd, tmp_path = tempfile.mkstemp(suffix=suffix)
    os.close(fd)

    try:
        audio_file.save(tmp_path)
        file_size_kb = os.path.getsize(tmp_path) / 1024
        logger.info("Received audio: %s (%.1f KB)", filename, file_size_kb)

        t_start = time.perf_counter()

        # 1. Primary transcription pass using original model (UNTOUCHED)
        segments_gen, info = model.transcribe(
            tmp_path,
            beam_size=BEAM_SIZE,
            vad_filter=VAD_FILTER,
        )

        segments = []
        raw_parts = []
        for seg in segments_gen:
            segments.append({
                "id":    seg.id,
                "start": round(seg.start, 3),
                "end":   round(seg.end, 3),
                "text":  seg.text,
            })
            raw_parts.append(seg.text)

        processing_time = time.perf_counter() - t_start
        raw_text = " ".join(raw_parts).strip()
        cleaned  = _clean_text(raw_text)

        # 2. Secondary Speech-to-English Translation pass (Additive)
        translated_text = cleaned
        trans_time = 0.0
        try:
            t_trans_start = time.perf_counter()
            translated_text = translate_audio_to_english(tmp_path)
            trans_time = time.perf_counter() - t_trans_start
        except Exception as trans_exc:
            logger.warning("Translation pass failed: %s", trans_exc)
            translated_text = cleaned

        result = {
            "text":                        cleaned,
            "translated_text":            translated_text,
            "raw_text":                    raw_text,
            "language":                    info.language,
            "language_probability":        round(info.language_probability, 4),
            "duration":                    round(info.duration, 3),
            "processing_time":             round(processing_time, 3),
            "translation_processing_time": round(trans_time, 3),
            "segments":                    segments,
        }

        logger.info(
            "Transcribed in %.2fs (trans=%.2fs) | lang=%s (%.0f%%) | '%s' -> '%s'",
            processing_time,
            trans_time,
            info.language,
            info.language_probability * 100,
            cleaned[:60],
            translated_text[:60],
        )
        return jsonify(result)

    except Exception as exc:
        logger.exception("Transcription error")
        return jsonify({"error": f"Transcription failed: {exc}"}), 500

    finally:
        if os.path.exists(tmp_path):
            os.remove(tmp_path)


# ── Start Flask in a background thread ────────────────────────────────
FLASK_PORT = 5000

def run_flask():
    app.run(host="0.0.0.0", port=FLASK_PORT, use_reloader=False)

flask_thread = threading.Thread(target=run_flask, daemon=True)
flask_thread.start()

time.sleep(2)  # wait for Flask to start

# ── Open ngrok tunnel ──────────────────────────────────────────────────
public_url = ngrok.connect(FLASK_PORT, bind_tls=True).public_url

print("\n" + "=" * 60)
print(f"  STT API is LIVE at: {public_url}")
print(f"  Transcribe endpoint: {public_url}/transcribe")
print(f"  Health check:        {public_url}/health")
print("=" * 60)
print()
print("Copy the URL above and set it in your local .env:")
print(f"  STT_API_URL={public_url}/transcribe")
print(f"  STT_USE_REMOTE=true")
print()
print("Keep this notebook running. Restart Cells 2–5 if the runtime is reset.")

# %% [markdown]
# ## Testing the API
#
# You can test the endpoint directly from Colab with the cell below, or use `curl` locally:
#
# ```bash
# curl -X POST <your-ngrok-url>/transcribe \
#   -F 'audio=@/path/to/your/audio.wav' | python -m json.tool
# ```

# %%
# ── Cell 6 (optional): Quick self-test ────────────────────────────────
# Downloads a short public-domain WAV and round-trips it through the API.
import requests
import urllib.request

TEST_WAV_URL = "https://www.soundhelix.com/examples/mp3/SoundHelix-Song-1.mp3"

# Use a local file if you have one:
# test_path = "/content/my_audio.wav"

test_path = "/tmp/test_audio.mp3"
urllib.request.urlretrieve(TEST_WAV_URL, test_path)

with open(test_path, "rb") as f:
    resp = requests.post(f"http://localhost:{FLASK_PORT}/transcribe", files={"audio": f})

print(resp.status_code)
import json; print(json.dumps(resp.json(), indent=2))
